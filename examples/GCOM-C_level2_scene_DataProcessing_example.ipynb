# %%
# !pip install git+https://github.com/Shima-shoki/GcomcTool
# Out:
# ...
#   Cloning https://github.com/Shima-shoki/GcomcTool to c:\users\shoki\appdata\local\temp\pip-req-build-jg17wvcg
# ...
#   Created wheel for GcomcTool: filename=GcomcTool-2.0-py3-none-any.whl size=9296 sha256=380a758e5ecf5d2c23a0512db764903af87d8c38780ad9307aaf93af2aa6947b
#   Stored in directory: C:\Users\shoki\AppData\Local\Temp\pip-ephem-wheel-cache-ygxsus50\wheels\d8\30\74\4eeb573ce9283cafa2a3c616ad2f55c6518cdf58e9518a99b1
# Successfully built GcomcTool
# ...
#   Running command git clone -q https://github.com/Shima-shoki/GcomcTool 'C:\Users\shoki\AppData\Local\Temp\pip-req-build-jg17wvcg'

# %%
from GcomcTool.GcomcTool import GcomCpy

# %%
target=GcomCpy()
# Out:
# This program was tested under the GDAL 3.2.2.

# %%
path_to_product='C:/Users/shoki/Desktop/downloadTest/GC1SG1_202001050130A05010_L2SG_IWPRQ_2000.h5'
target.show_subdatasets(False,path_to_product)
# Out:
# <KeysViewHDF5 ['CDOM', 'CHLA', 'Line_tai93', 'QA_flag', 'TSM']>

# %%
file_path='C:/Users/shoki/Desktop/downloadTest/GC1SG1_202001050130A05010_L2SG_IWPRQ_2000.h5'
subdataset='CHLA'
output_path='C:/Users/shoki/Desktop/downloadTest/GC1SG1_202001050130A05010_L2SG_IWPRQ_2000.tif'
target.reprojection_scene(file_path,subdataset,output_path)

# %% [markdown]
# ![CHLA_output.png](attachment:CHLA_output.png)
