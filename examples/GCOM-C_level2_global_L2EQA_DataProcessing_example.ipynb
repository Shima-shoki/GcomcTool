# %%
# !pip install git+https://github.com/Shima-shoki/GcomcTool
# Out:
# Collecting git+https://github.com/Shima-shoki/GcomcTool
#   Cloning https://github.com/Shima-shoki/GcomcTool to c:\users\shoki\appdata\local\temp\pip-req-build-6vbr4d9o
# Building wheels for collected packages: GcomcTool
#   Building wheel for GcomcTool (setup.py): started
#   Building wheel for GcomcTool (setup.py): finished with status 'done'
#   Created wheel for GcomcTool: filename=GcomcTool-2.0-py3-none-any.whl size=9296 sha256=ab751ce9f1b1591bdd33b75f902ed5e3b535f0cb13884aff2289e6b78ebaae20
#   Stored in directory: C:\Users\shoki\AppData\Local\Temp\pip-ephem-wheel-cache-8bbwd96i\wheels\d8\30\74\4eeb573ce9283cafa2a3c616ad2f55c6518cdf58e9518a99b1
# Successfully built GcomcTool
# Installing collected packages: GcomcTool
# Successfully installed GcomcTool-2.0
#   Running command git clone -q https://github.com/Shima-shoki/GcomcTool 'C:\Users\shoki\AppData\Local\Temp\pip-req-build-6vbr4d9o'

# %%
from GcomcTool.GcomcTool import GcomCpy

# %%
target=GcomCpy()
# Out:
# This program was tested under the GDAL 3.2.2.

# %%
target.filter_products_global(product_name='ARPL',
                               date_start='2020-01-01',
                               date_end='2020-01-05',
                               user_name='SHIMADA',
                               orbit="D",
                               product_type="ATMOS",
                               level=2,
                               version=2,
                               projection="A",
                               period="01D")
# Out:
# Filtering process has started...
# ['/standard/GCOM-C/GCOM-C.SGLI/L2.ATMOS.ARPL.Global/2/2020/01/GC1SG1_20200101D01D_A0000_L2SG_ARPLF_2000.h5']
# ['/standard/GCOM-C/GCOM-C.SGLI/L2.ATMOS.ARPL.Global/2/2020/01/GC1SG1_20200102D01D_A0000_L2SG_ARPLF_2000.h5']
# ['/standard/GCOM-C/GCOM-C.SGLI/L2.ATMOS.ARPL.Global/2/2020/01/GC1SG1_20200103D01D_A0000_L2SG_ARPLF_2000.h5']
# ['/standard/GCOM-C/GCOM-C.SGLI/L2.ATMOS.ARPL.Global/2/2020/01/GC1SG1_20200104D01D_A0000_L2SG_ARPLF_2000.h5']
# ['/standard/GCOM-C/GCOM-C.SGLI/L2.ATMOS.ARPL.Global/2/2020/01/GC1SG1_20200105D01D_A0000_L2SG_ARPLF_2000.h5']

# %%
target.get_products('C:/Users/shoki/Desktop/downloadTest')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:05<00:00,  1.20s/it]

# %%
target.show_subdatasets()
# Out:
# <KeysViewHDF5 ['ARAE_pol_land', 'AROT_pol_land', 'ARSSA_pol_land', 'QA_flag']>

# %%
#If "temporal_merge" is "True", 
#the program automatically merges all the downloaded products with the method specified by "merge_method".

target.reproject_all_global('ARAE_pol_land',
                           'ARAP_global',
                           temporal_merge=True,
                           merge_method='mean')

#This will return an error saying that the image is not referenced. 
#However, since the image is not in a usual projection, the georeferencing works couldn't be implemented.
# Out:
# C:\Users\shoki\Anaconda3\lib\site-packages\rasterio\__init__.py:220: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %% [markdown]
# This is the output image of the above processes.

# %% [markdown]
# ![ARAP_output.png](attachment:ARAP_output.png)

# %%
target.clean_up()
