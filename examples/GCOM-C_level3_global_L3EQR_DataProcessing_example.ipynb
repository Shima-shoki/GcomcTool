# %%
# !pip install git+https://github.com/Shima-shoki/GcomcTool
# Out:
# Collecting git+https://github.com/Shima-shoki/GcomcTool
#   Running command git clone -q https://github.com/Shima-shoki/GcomcTool 'C:\Users\shoki\AppData\Local\Temp\pip-req-build-twf4whee'
#   Cloning https://github.com/Shima-shoki/GcomcTool to c:\users\shoki\appdata\local\temp\pip-req-build-twf4whee
# Building wheels for collected packages: GcomcTool
#   Building wheel for GcomcTool (setup.py): started
#   Building wheel for GcomcTool (setup.py): finished with status 'done'
#   Created wheel for GcomcTool: filename=GcomcTool-2.0-py3-none-any.whl size=9296 sha256=26b5f3afc241ba6efd2b4113fa80f31c8273e37af23202278be8f65c88fbd463
#   Stored in directory: C:\Users\shoki\AppData\Local\Temp\pip-ephem-wheel-cache-umtp4aug\wheels\d8\30\74\4eeb573ce9283cafa2a3c616ad2f55c6518cdf58e9518a99b1
# Successfully built GcomcTool
# Installing collected packages: GcomcTool
# Successfully installed GcomcTool-2.0

# %%
from GcomcTool.GcomcTool import GcomCpy

# %%
target=GcomCpy()
# Out:
# This program was tested under the GDAL 3.2.2.

# %%
target.filter_products_global(product_name='CHLA',
                               date_start='2020-01-01',
                               date_end='2020-01-05',
                               user_name='SHIMADA',
                               orbit="D",
                               product_type="OCEAN",
                               level=3,
                               version=2,
                               projection="D",
                               period="01D")
# Out:
# Filtering process has started...
# ['/standard/GCOM-C/GCOM-C.SGLI/L3.OCEAN.CHLA/2/2020/01/GC1SG1_20200101D01D_D0000_3MSG_CHLAF_2000.h5']
# ['/standard/GCOM-C/GCOM-C.SGLI/L3.OCEAN.CHLA/2/2020/01/GC1SG1_20200102D01D_D0000_3MSG_CHLAF_2000.h5']
# ['/standard/GCOM-C/GCOM-C.SGLI/L3.OCEAN.CHLA/2/2020/01/GC1SG1_20200103D01D_D0000_3MSG_CHLAF_2000.h5']
# ['/standard/GCOM-C/GCOM-C.SGLI/L3.OCEAN.CHLA/2/2020/01/GC1SG1_20200104D01D_D0000_3MSG_CHLAF_2000.h5']
# ['/standard/GCOM-C/GCOM-C.SGLI/L3.OCEAN.CHLA/2/2020/01/GC1SG1_20200105D01D_D0000_3MSG_CHLAF_2000.h5']

# %%
target.get_products('C:/Users/shoki/Desktop/downloadTest')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:04<00:00,  1.08it/s]

# %%
target.show_subdatasets()
# Out:
# <KeysViewHDF5 ['CHLA_AVE', 'CHLA_QA_flag']>

# %%
#If "temporal_merge" is "True", 
#the program automatically merges all the downloaded products with the method specified by "merge_method".

target.reproject_all_global(sub_dataset='CHLA_AVE',
                           folder_name='CHLA_global',
                           temporal_merge=True,
                           merge_method='mean')

#The L3EQR global product is geo-referenced.

# %% [markdown]
# This is the output image of the above processes.
# ![CHLA_output.png](attachment:CHLA_output.png)

# %%
target.clean_up()
