# %%
# !pip install git+https://github.com/Shima-shoki/GcomcTool
# Out:
# Collecting git+https://github.com/Shima-shoki/GcomcTool
#   Cloning https://github.com/Shima-shoki/GcomcTool to c:\users\shoki\appdata\local\temp\pip-req-build-a4nkv5am
# Building wheels for collected packages: GcomcTool
#   Building wheel for GcomcTool (setup.py): started
#   Building wheel for GcomcTool (setup.py): finished with status 'done'
#   Created wheel for GcomcTool: filename=GcomcTool-2.0-py3-none-any.whl size=9296 sha256=3cab61f71446f4e287d6b7cf6e25581c3715574374ac868e2c20584f8de9fa81
#   Stored in directory: C:\Users\shoki\AppData\Local\Temp\pip-ephem-wheel-cache-8c1z6d7o\wheels\d8\30\74\4eeb573ce9283cafa2a3c616ad2f55c6518cdf58e9518a99b1
# Successfully built GcomcTool
# Installing collected packages: GcomcTool
# Successfully installed GcomcTool-2.0
#   Running command git clone -q https://github.com/Shima-shoki/GcomcTool 'C:\Users\shoki\AppData\Local\Temp\pip-req-build-a4nkv5am'

# %%
from GcomcTool.GcomcTool import GcomCpy

# %%
target=GcomCpy()
# Out:
# This program was tested under the GDAL 3.2.2.

# %%
target.filter_products_global(product_name='SIST',
                               date_start='2020-01-01',
                               date_end='2020-01-05',
                               user_name='SHIMADA',
                               orbit="D",
                               product_type="CRYOS",
                               level=3,
                               version=2,
                               projection="S",
                               period="01D")
# Out:
# Filtering process has started...
# ['/standard/GCOM-C/GCOM-C.SGLI/L3.CRYOS.SIST/2/2020/01/GC1SG1_20200101D01D_S0000_3MSG_SISTF_2000.h5']
# ['/standard/GCOM-C/GCOM-C.SGLI/L3.CRYOS.SIST/2/2020/01/GC1SG1_20200102D01D_S0000_3MSG_SISTF_2000.h5']
# ['/standard/GCOM-C/GCOM-C.SGLI/L3.CRYOS.SIST/2/2020/01/GC1SG1_20200103D01D_S0000_3MSG_SISTF_2000.h5']
# ['/standard/GCOM-C/GCOM-C.SGLI/L3.CRYOS.SIST/2/2020/01/GC1SG1_20200104D01D_S0000_3MSG_SISTF_2000.h5']
# ['/standard/GCOM-C/GCOM-C.SGLI/L3.CRYOS.SIST/2/2020/01/GC1SG1_20200105D01D_S0000_3MSG_SISTF_2000.h5']

# %%
target.get_products('C:/Users/shoki/Desktop/downloadTest')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:02<00:00,  2.26it/s]

# %%
target.show_subdatasets()
# Out:
# <KeysViewHDF5 ['SIST_AVE', 'SIST_QA_flag']>

# %%
#If "temporal_merge" is "True", 
#the program automatically merges all the downloaded products with the method specified by "merge_method".

target.reproject_all_global(sub_dataset='SIST_AVE',
                           folder_name='SIST_polar',
                           temporal_merge=True,
                           merge_method='mean')

#This will return an error saying that the image is not referenced. 
#However, since the image is not in a usual projection, the georeferencing works couldn't be implemented.

# %% [markdown]
# This is the output image of the above processes.
# ![polar.png](attachment:polar.png)

# %%
target.clean_up()
